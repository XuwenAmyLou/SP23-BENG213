# %% [markdown]
# Questions:
# 1. In question 1.2.3, how do we check what PC1 and PC2 are
# 2. In 1.3, are we talking about the coefficient of a sample point or of all of them as a whole

# %% [markdown]
# # Homework 2: Unsupervised Learning
#
# Due Date: Mon, May 8, 2023 at Midnight PST (Submit this .ipynb file on Canvas)
#
# Your Name: **Amy Lou**
#
# <span style="color:red">100 total points</span>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#K-means-clustering" data-toc-modified-id="K-means-clustering-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>K-means clustering</a></span><ul class="toc-item"><li><span><a href="#Describe-K-means" data-toc-modified-id="Describe-K-means-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Describe K-means</a></span></li><li><span><a href="#Compute-clusters-of-samples-for-K-=-10" data-toc-modified-id="Compute-clusters-of-samples-for-K-=-10-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Compute clusters of samples for K = 10</a></span><ul class="toc-item"><li><span><a href="#Obtain-cluster-labels" data-toc-modified-id="Obtain-cluster-labels-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Obtain cluster labels</a></span></li><li><span><a href="#Visualize-the-clusters-with-PCA" data-toc-modified-id="Visualize-the-clusters-with-PCA-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Visualize the clusters with PCA</a></span></li><li><span><a href="#Discuss-one-of-the-clusters" data-toc-modified-id="Discuss-one-of-the-clusters-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Discuss one of the clusters</a></span></li></ul></li><li><span><a href="#Describe-the-silhouette-coefficient" data-toc-modified-id="Describe-the-silhouette-coefficient-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Describe the silhouette coefficient</a></span></li><li><span><a href="#Characterize-the-samples-using-silhouette-coefficients" data-toc-modified-id="Characterize-the-samples-using-silhouette-coefficients-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Characterize the samples using silhouette coefficients</a></span></li><li><span><a href="#Choose-an-optimal-K-with-the-Elbow-Method" data-toc-modified-id="Choose-an-optimal-K-with-the-Elbow-Method-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Choose an optimal K with the Elbow Method</a></span></li></ul></li><li><span><a href="#Agglomerative-Hierarchical-Clustering" data-toc-modified-id="Agglomerative-Hierarchical-Clustering-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Agglomerative Hierarchical Clustering</a></span><ul class="toc-item"><li><span><a href="#Describe-Agglomerative-Hierarchical-Clustering" data-toc-modified-id="Describe-Agglomerative-Hierarchical-Clustering-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Describe Agglomerative Hierarchical Clustering</a></span></li><li><span><a href="#Compute-Agglomerative-Hierarchical-Clusters" data-toc-modified-id="Compute-Agglomerative-Hierarchical-Clusters-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Compute Agglomerative Hierarchical Clusters</a></span><ul class="toc-item"><li><span><a href="#Create-dendrograms-for-two-linkage-types" data-toc-modified-id="Create-dendrograms-for-two-linkage-types-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Create dendrograms for two linkage types</a></span></li><li><span><a href="#Obtain-cluster-labels-from-dendrograms" data-toc-modified-id="Obtain-cluster-labels-from-dendrograms-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Obtain cluster labels from dendrograms</a></span></li></ul></li></ul></li><li><span><a href="#Principal-Component-Analysis" data-toc-modified-id="Principal-Component-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Principal Component Analysis</a></span><ul class="toc-item"><li><span><a href="#Describe-PCA" data-toc-modified-id="Describe-PCA-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Describe PCA</a></span></li><li><span><a href="#Covariance" data-toc-modified-id="Covariance-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Covariance</a></span><ul class="toc-item"><li><span><a href="#Compute-and-visualize-the-covariance-matrix." data-toc-modified-id="Compute-and-visualize-the-covariance-matrix.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Compute and visualize the covariance matrix.</a></span></li></ul></li><li><span><a href="#PCA-of-the-data" data-toc-modified-id="PCA-of-the-data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>PCA of the data</a></span><ul class="toc-item"><li><span><a href="#Highest-weighted-genes-in-PC-1-&amp;-PC-2" data-toc-modified-id="Highest-weighted-genes-in-PC-1-&amp;-PC-2-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Highest weighted genes in PC 1 &amp; PC 2</a></span></li><li><span><a href="#Generate-a-biplot" data-toc-modified-id="Generate-a-biplot-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Generate a biplot</a></span></li><li><span><a href="#Are-any-PCs-correlated-with-growth-rate?" data-toc-modified-id="Are-any-PCs-correlated-with-growth-rate?-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Are any PCs correlated with growth rate?</a></span></li></ul></li><li><span><a href="#Explained-Variance" data-toc-modified-id="Explained-Variance-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Explained Variance</a></span><ul class="toc-item"><li><span><a href="#Plot-the-Explained-Variance" data-toc-modified-id="Plot-the-Explained-Variance-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Plot the Explained Variance</a></span></li><li><span><a href="#&quot;Denoise&quot;-your-dataset" data-toc-modified-id="&quot;Denoise&quot;-your-dataset-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>"Denoise" your dataset</a></span></li></ul></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn import cluster, metrics # these will be useful
from sklearn import decomposition, metrics # these will be useful

# read in the data
file_name = 'Homework_Data.xlsx'

data = pd.read_excel(file_name, 
                     sheet_name = 'Expression Data',
                     index_col = 0)
sample_table = pd.read_excel(file_name,
                             sheet_name = 'Experimental Conditions',
                             index_col = 0)
gene_table = pd.read_excel(file_name,
                           sheet_name = 'Gene Information',
                           index_col = 0)

# %% [markdown]
# ## K-means clustering
#
# ### Describe K-means
#
# Use words to describe:
#
# 1. The overall criteria for K-means clustering
# 2. The algorithm for computing K-means clustering
# 3. Its strengths and weaknesses
#
# <span style="color:red">5 points</span>

# %% [markdown]
# 1. K-means clustering essentially idnetifies k(k defined by user ahead of time) clusters within the data. Whether a sample belong to a certain cluster or not depends on the distance of the sample to the centroids of that specific cluster. It is an algorithm that clusters the samples together based on their distance to the cluster centroids.
#
# 2. The iterative algorithm will randomly pick k starting points as the initial centroids. During each round, for each sample point, the algorithm calculates its distance to the centroids. The sample point is then clustered to the centroid that it is closest to. After assigning each sample point, the algorithm calculate a new centroid for each cluster based on the sample points that got assigned to it during that round. This is the end of the initial loop. Then the loop repeats itself until specific stopping criteria is met (for example, the assignment no longer changes between rounds).
#
# 3. The K-means clustering algorithm is advantageous because it is relatively simple to understand and implement (even for large dataset, the code remains similar). It will always give a clustering result in the end (however the quality of the clustering result is not gauranteed). The user can also visually inspect the data and pick the initial starting points if they like (this will likely reduce the runtime).
# Its weakness is that the user must specify a k value to start with. This means that the user must have some prior knowledge about the grouping of the data, or that will have to experiment to pick the best k value. It is also a method heavily influenced by outliers and initializaiton. The resulting cluster can be difficult to interpret or might not make sense (especially for certain data shape).

# %% [markdown]
# ### Compute clusters of samples for K = 10
#
# #### Obtain cluster labels
#
# Compute the K-means clustering with K = 10. You should end up with a pd.Series where each sample is mapped to a cluster number.
#
# I recommend specifying a random_state when you perform the clustering (it is a function input). The value you use doesn't matter, but keeping it consistent will allow you to re-run your code without changing the outputs.
#
# <span style="color:red">3 points</span>

# %%
#transpose the data
data_T = data.copy()
data_T = data_T.T
kmeans = cluster.KMeans(n_clusters=10, random_state=0).fit(data_T)

# %%
# RIP MY CODE ;-;

# #initial loop
# random_state = [] # initial centroids
# K = [] # assignment list
# Q2 = []

# # initialization
# # This scould be random, for this problem, used a fixed initial start to obtain consistent clustering result
# for i in range(10):
#     temp = data.iloc[:,10*i+1].values.tolist()
#     random_state.append(temp)
#     K.append([])

# # initial assignment
# # loop through every sample
# for i in range(102):
#     temp = sum(data.iloc[:,i].values.tolist())
#     K_diff = []
    
#     # for each sample, compare agaisnt the centroids
#     for j in range(10):
#         diff = abs(sum(random_state[j]) - temp)
#         K_diff.append(diff)
    
#     # sample assignment
#     min_index = K_diff.index(min(K_diff)) 
#     K[min_index].append(i)
#     Q2.append(min_index)

# centroids = []
# # calculate new means
# for i in range(10):
#     next_centroid = [0]*3887
    
#     # iterate through each sample point
#     for j in K[i]:
#         next_centroid = np.add(next_centroid,data.iloc[:,j].values.tolist())
    
#     # get the new average
#     for j in range(3887):
#         next_centroid[j] = next_centroid[j]/len(K[i])
    
#     # put in the centroids
#     centroids.append(next_centroid)

# %% [markdown]
# #### Visualize the clusters with PCA
#
# You will work directly with PCA later in the assignment. For now, you can use the function provided below to create a PCA plot of your data and color it by the clusters you computed. This creates a two-dimensional plot that captures as much of the 3,887-dimensional gene space as possible. It will therefore give you an idea of where each of your clusters are in gene-space and roughly how much they overlap.
#
# For the future, note that this plot is not a complete PCA biplot - it should include the explained variance in the axes labels and have arrows to indicate top gene directions (you will need to add those on your own later in the assignment).
#
# <span style="color:red">2 points</span>

# %%
from sklearn.decomposition import PCA
import matplotlib.cm as cm

def PCA_cluster_plot(data, cluster_labels, ax = None):
    """
    Parameters:
        data: the pd.DataFrame of gene expression data
        cluster_labels: a pd.Series with a cluster label
            for each column of data
        ax: if None, draw a new figure. else, populate these axes.
    Returns:
        ax: the plt.axes object of a PCA plot labeled by cluster
    """
    
    # check for bad input
    if isinstance(cluster_labels, pd.Series):
        if not(cluster_labels.index.equals(data.columns)):
            raise ValueError('cluster_labels.index doesn\'t match data.columns')
    else:
        raise TypeError('cluster_labels isn\'t a pd.Series')
    
    # compute PCA, save as dataframe with condition labels
    data_norm = stats.zscore(data, axis=1)
    data_pc = PCA().fit_transform(data_norm.T)
    data_pc = pd.DataFrame(data_pc, index = data.columns)
    
    # get the unique clusters (supports naming if desired)
    unique_clusters = np.sort(cluster_labels.unique())
    
    # prepare a long list of colors
    colors = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple',
              'tab:brown','tab:pink','tab:gray','tab:olive', 'tab:cyan',
              'black', 'salmon', 'chocolate', 'orange', 'gold', 'lawngreen',
              'turquoise', 'steelblue', 'navy', 'violet', 'deeppink',
              'firebrick', 'sandybrown','olivedrab','darkgreen', 'aqua',
              'slategray', 'blue', 'fuschia', 'pink']
    
    # this code only runs if you have a ton of labels
    while len(colors) < len(cluster_labels.unique()):
        colors = colors + colors
    
    # make the plot
    if ax is None:
        fig, ax = plt.subplots()
    ax.set_xlabel('PC1', fontsize = 16)
    ax.set_ylabel('PC2', fontsize = 16)
    
    # iterate through each cluster label
    for clust, color in zip(unique_clusters, colors):
        
        # get the samples of this cluster
        samples = cluster_labels.index[cluster_labels == clust]
        
        # add to plot
        ax.scatter(data_pc.loc[samples, 0],
                   data_pc.loc[samples, 1],
                   label = clust, color = color)
    
    # add legend
    ax.legend(bbox_to_anchor = (1,1))
    
    return ax

# %%
# visualize the results
labels = pd.Series(kmeans.labels_,data.columns)
PCA_cluster_plot(data, labels, ax = None)
# Out:
# <AxesSubplot:xlabel='PC1', ylabel='PC2'>

# %% [markdown]
# #### Discuss one of the clusters
#
# Choose one of the clusters. Display the sample_table entries for the samples in that cluster; is there a common theme or defining characteristic for this cluster? Where does this cluster appear on the PC plot above (e.g. at extremes, in middle, etc), and does its location make sense with its defining characteristics?
#
# <span style="color:red">5 points</span>

# %%
#  cluster 9 seems interesting, get information based on kmeans.labels_
cluster_9 = data[['rpoB__rpoBE672K_glc__1','rpoB__rpoBE672K_glc__2','rpoB__rpoBE672K_lb__1','rpoB__rpoBE672K_lb__2']]
sample_table.loc[['rpoB__rpoBE672K_glc__1','rpoB__rpoBE672K_glc__2','rpoB__rpoBE672K_lb__1','rpoB__rpoBE672K_lb__2']]
# Out:
#                                 Study   Condition ID  Replicate #  \
# Sample ID
# rpoB__rpoBE672K_glc__1  RpoB Knock-in  rpoBE672K_glc            1
# rpoB__rpoBE672K_glc__2  RpoB Knock-in  rpoBE672K_glc            2
# rpoB__rpoBE672K_lb__1   RpoB Knock-in   rpoBE672K_lb            1
# rpoB__rpoBE672K_lb__2   RpoB Knock-in   rpoBE672K_lb            2
#
#                                             Strain Description Base Media  \
# Sample ID
# rpoB__rpoBE672K_glc__1  Escherichia coli K-12 MG1655 rpoBE672K         M9
# rpoB__rpoBE672K_glc__2  Escherichia coli K-12 MG1655 rpoBE672K         M9
# rpoB__rpoBE672K_lb__1   Escherichia coli K-12 MG1655 rpoBE672K         LB
# rpoB__rpoBE672K_lb__2   Escherichia coli K-12 MG1655 rpoBE672K         LB
#
#                        Carbon Source (g/L) Nitrogen Source (g/L)  \
# Sample ID
# rpoB__rpoBE672K_glc__1          glucose(4)              NH4Cl(1)
# rpoB__rpoBE672K_glc__2          glucose(4)              NH4Cl(1)
# rpoB__rpoBE672K_lb__1                  NaN                   NaN
# rpoB__rpoBE672K_lb__2                  NaN                   NaN
#
#                        Electron Acceptor        Trace Element Mixture  \
# Sample ID
# rpoB__rpoBE672K_glc__1                O2  sauer trace element mixture
# rpoB__rpoBE672K_glc__2                O2  sauer trace element mixture
# rpoB__rpoBE672K_lb__1                 O2                          NaN
# rpoB__rpoBE672K_lb__2                 O2                          NaN
#
#                        Supplement  Temperature (C)   pH Culture Type  \
# Sample ID
# rpoB__rpoBE672K_glc__1        NaN               37  7.0        Batch
# rpoB__rpoBE672K_glc__2        NaN               37  7.0        Batch
# rpoB__rpoBE672K_lb__1         NaN               37  7.0        Batch
# rpoB__rpoBE672K_lb__2         NaN               37  7.0        Batch
#
#                         Growth Rate (1/hr) Sequencing Machine  \
# Sample ID
# rpoB__rpoBE672K_glc__1                0.88              MiSeq
# rpoB__rpoBE672K_glc__2                0.88              MiSeq
# rpoB__rpoBE672K_lb__1                 1.40              MiSeq
# rpoB__rpoBE672K_lb__2                 1.40              MiSeq
#
#                        Additional Details  Biological Replicates  \
# Sample ID
# rpoB__rpoBE672K_glc__1                NaN                      2
# rpoB__rpoBE672K_glc__2                NaN                      2
# rpoB__rpoBE672K_lb__1                 NaN                      2
# rpoB__rpoBE672K_lb__2                 NaN                      2
#
#                                                        DOI       GEO
# Sample ID
# rpoB__rpoBE672K_glc__1  doi.org/10.1016/j.cels.2016.04.003  GSE59377
# rpoB__rpoBE672K_glc__2  doi.org/10.1016/j.cels.2016.04.003  GSE59377
# rpoB__rpoBE672K_lb__1   doi.org/10.1016/j.cels.2016.04.003  GSE59377
# rpoB__rpoBE672K_lb__2   doi.org/10.1016/j.cels.2016.04.003  GSE59377

# %%
pd.set_option('display.max_rows', None)
sample_table
# Out:
#                                      Study     Condition ID  Replicate #  \
# Sample ID
# base__wt_glc__1                       Base           wt_glc            1
# base__wt_glc__2                       Base           wt_glc            2
# fur__wt_dpd__1                         Fur           wt_dpd            1
# fur__wt_dpd__2                         Fur           wt_dpd            2
# fur__wt_fe__1                          Fur            wt_fe            1
# fur__wt_fe__2                          Fur            wt_fe            2
# fur__delfur_dpd__1                     Fur       delfur_dpd            1
# fur__delfur_dpd__2                     Fur       delfur_dpd            2
# fur__delfur_fe2__1                     Fur       delfur_fe2            1
# fur__delfur_fe2__2                     Fur       delfur_fe2            2
# acid__wt_ph5__1                       Acid           wt_ph5            1
# acid__wt_ph5__2                       Acid           wt_ph5            2
# acid__delgadx_ph5__1                  Acid      delgadx_ph5            1
# acid__delgadx_ph5__2                  Acid      delgadx_ph5            2
# acid__delgadw_ph5__1                  Acid      delgadw_ph5            1
# acid__delgadw_ph5__2                  Acid      delgadw_ph5            2
# acid__delgade_ph5__1                  Acid      delgade_ph5            1
# acid__delgade_ph5__2                  Acid      delgade_ph5            2
# oxidative__wt_pq__1              Oxidative            wt_pq            1
# oxidative__wt_pq__2              Oxidative            wt_pq            2
# oxidative__deloxyr_pq__1         Oxidative       deloxyr_pq            1
# oxidative__deloxyr_pq__2         Oxidative       deloxyr_pq            2
# oxidative__delsoxr_pq__1         Oxidative       delsoxr_pq            1
# oxidative__delsoxr_pq__2         Oxidative       delsoxr_pq            2
# oxidative__delsoxs_pq__1         Oxidative       delsoxs_pq            1
# oxidative__delsoxs_pq__2         Oxidative       delsoxs_pq            2
# nac_ntrc__wt_csn__1               Nac/NtrC           wt_csn            1
# nac_ntrc__wt_csn__2               Nac/NtrC           wt_csn            2
# nac_ntrc__wt_cytd__1              Nac/NtrC          wt_cytd            1
# nac_ntrc__wt_cytd__2              Nac/NtrC          wt_cytd            2
# nac_ntrc__wt_gln__1               Nac/NtrC           wt_gln            1
# nac_ntrc__wt_gln__2               Nac/NtrC           wt_gln            2
# nac_ntrc__bw_delnac_csn__1        Nac/NtrC    bw_delnac_csn            1
# nac_ntrc__bw_delnac_csn__2        Nac/NtrC    bw_delnac_csn            2
# nac_ntrc__bw_delnac_cytd__1       Nac/NtrC   bw_delnac_cytd            1
# nac_ntrc__bw_delnac_cytd__2       Nac/NtrC   bw_delnac_cytd            2
# nac_ntrc__bw_delnac_gln__1        Nac/NtrC    bw_delnac_gln            1
# nac_ntrc__bw_delnac_gln__2        Nac/NtrC    bw_delnac_gln            2
# nac_ntrc__bw_delnac_nh4__1        Nac/NtrC    bw_delnac_nh4            1
# nac_ntrc__bw_delnac_nh4__2        Nac/NtrC    bw_delnac_nh4            2
# misc__wt_no_te__1                     Misc         wt_no_te            1
# misc__wt_no_te__2                     Misc         wt_no_te            2
# misc__bw_delcbl__1                    Misc        bw_delcbl            1
# misc__bw_delcbl__2                    Misc        bw_delcbl            2
# misc__bw_delfabr__1                   Misc       bw_delfabr            1
# misc__bw_delfabr__2                   Misc       bw_delfabr            2
# misc__bw_delfadr__1                   Misc       bw_delfadr            1
# misc__bw_delfadr__2                   Misc       bw_delfadr            2
# omics__wt_glu__1                     Omics           wt_glu            1
# omics__wt_glu__2                     Omics           wt_glu            2
# omics__wt_gly__1                     Omics           wt_gly            1
# omics__wt_gly__2                     Omics           wt_gly            2
# omics__wt_thr__1                     Omics           wt_thr            1
# omics__wt_thr__2                     Omics           wt_thr            2
# omics__bw_ac__1                      Omics            bw_ac            1
# omics__bw_ac__2                      Omics            bw_ac            2
# omics__bw_fum__1                     Omics           bw_fum            1
# omics__bw_fum__2                     Omics           bw_fum            2
# omics__bw_glc__1                     Omics           bw_glc            1
# omics__bw_glc__2                     Omics           bw_glc            2
# omics__bw_pyr__1                     Omics           bw_pyr            1
# omics__bw_pyr__2                     Omics           bw_pyr            2
# ompr__wt_nacl__1                      OmpR          wt_nacl            1
# ompr__bw_delompr_nacl__1              OmpR  bw_delompr_nacl            1
# ompr__bw_delompr_nacl__2              OmpR  bw_delompr_nacl            2
# minspan__wt_ade__1                 MinSpan           wt_ade            1
# minspan__wt_glc__1                 MinSpan           wt_glc            1
# minspan__wt_glc__2                 MinSpan           wt_glc            2
# minspan__wt_glc__3                 MinSpan           wt_glc            3
# minspan__wt_glc__4                 MinSpan           wt_glc            4
# minspan__wt_glc_anaero__1          MinSpan    wt_glc_anaero            1
# minspan__wt_glc_anaero__2          MinSpan    wt_glc_anaero            2
# minspan__wt_trp__1                 MinSpan           wt_trp            1
# minspan__bw_delcra_glc__1          MinSpan    bw_delcra_glc            1
# minspan__bw_delcra_glc__2          MinSpan    bw_delcra_glc            2
# minspan__bw_delcra_trp__1          MinSpan    bw_delcra_trp            1
# minspan__bw_delmntr__1             MinSpan       bw_delmntr            1
# minspan__bw_delnac_ade__1          MinSpan    bw_delnac_ade            1
# acid__delgade_ph5__2                M9          glucose(2)
# oxidative__wt_pq__1                 M9          glucose(2)
# oxidative__wt_pq__2                 M9          glucose(2)
# oxidative__deloxyr_pq__1            M9          glucose(2)
# oxidative__deloxyr_pq__2            M9          glucose(2)
# oxidative__delsoxr_pq__1            M9          glucose(2)
# oxidative__delsoxr_pq__2            M9          glucose(2)
# oxidative__delsoxs_pq__1            M9          glucose(2)
# oxidative__delsoxs_pq__2            M9          glucose(2)
# nac_ntrc__wt_csn__1                 W2          glucose(2)
# nac_ntrc__wt_csn__2                 W2          glucose(2)
# nac_ntrc__wt_cytd__1                W2          glucose(2)
# nac_ntrc__wt_cytd__2                W2          glucose(2)
# nac_ntrc__wt_gln__1                 W2          glucose(2)
# nac_ntrc__wt_gln__2                 W2          glucose(2)
# nac_ntrc__bw_delnac_csn__1          W2          glucose(2)
# nac_ntrc__bw_delnac_csn__2          W2          glucose(2)
# nac_ntrc__bw_delnac_cytd__1         W2          glucose(2)
# nac_ntrc__bw_delnac_cytd__2         W2          glucose(2)
# nac_ntrc__bw_delnac_gln__1          W2          glucose(2)
# nac_ntrc__bw_delnac_gln__2          W2          glucose(2)
# nac_ntrc__bw_delnac_nh4__1          M9          glucose(2)
# nac_ntrc__bw_delnac_nh4__2          M9          glucose(2)
# misc__wt_no_te__1                   M9          glucose(4)
# misc__wt_no_te__2                   M9          glucose(4)
# misc__bw_delcbl__1                  M9          glucose(4)
# misc__bw_delcbl__2                  M9          glucose(4)
# misc__bw_delfabr__1                 M9          glucose(4)
# misc__bw_delfabr__2                 M9          glucose(4)
# misc__bw_delfadr__1                 M9          glucose(4)
# misc__bw_delfadr__2                 M9          glucose(4)
# omics__wt_glu__1                    M9          glucose(4)
# omics__wt_glu__2                    M9          glucose(4)
# omics__wt_gly__1                    M9          glucose(4)
# omics__wt_gly__2                    M9          glucose(4)
# omics__wt_thr__1                    M9          glucose(4)
# omics__wt_thr__2                    M9          glucose(4)
# omics__bw_ac__1                     M9        acetate(3.5)
# omics__bw_ac__2                     M9        acetate(3.5)
# omics__bw_fum__1                    M9       fumarate(2.8)
# omics__bw_fum__2                    M9       fumarate(2.8)
# omics__bw_glc__1                    M9          glucose(5)
# omics__bw_glc__2                    M9          glucose(5)
# omics__bw_pyr__1                    M9       pyruvate(3.3)
# omics__bw_pyr__2                    M9       pyruvate(3.3)
# ompr__wt_nacl__1                    M9          glucose(2)
# ompr__bw_delompr_nacl__1            M9          glucose(2)
# ompr__bw_delompr_nacl__2            M9          glucose(2)
# minspan__wt_ade__1                  M9          glucose(4)
# minspan__wt_glc__1                  M9          glucose(4)
# minspan__wt_glc__2                  M9          glucose(4)
# minspan__wt_glc__3                  M9          glucose(4)
# minspan__wt_glc__4                  M9          glucose(4)
# minspan__wt_glc_anaero__1           M9          glucose(4)
# minspan__wt_glc_anaero__2           M9          glucose(4)
# minspan__wt_trp__1                  M9          glucose(4)
# minspan__bw_delcra_glc__1           M9          glucose(4)
# minspan__bw_delcra_glc__2           M9          glucose(4)
# minspan__bw_delcra_trp__1           M9          glucose(4)
# minspan__bw_delmntr__1              M9          glucose(4)
# minspan__bw_delnac_ade__1           M9          glucose(4)
# minspan__bw_delnac_glc__1           M9          glucose(4)
# cra_crp__wt_ac__1                   M9          acetate(2)
# cra_crp__wt_ac__2                   M9          acetate(2)
# cra_crp__wt_fru__1                  M9         fructose(2)
# cra_crp__wt_fru__2                  M9         fructose(2)
# cra_crp__delcra_ac__1               M9          acetate(2)
# cra_crp__delcra_ac__2               M9          acetate(2)
# cra_crp__delcra_fru__1              M9         fructose(2)
# cra_crp__delcra_fru__2              M9         fructose(2)
# cra_crp__delcra_glc__1              M9          glucose(2)
# cra_crp__delcra_glc__2              M9          glucose(2)
# rpoB__wt_031__1                     M9          glucose(4)
# rpoB__wt_044__1                     M9          glucose(4)
# rpoB__wt_lb__1                      LB                 NaN
# rpoB__wt_lb__2                      LB                 NaN
# rpoB__rpoBE546V_031__1              M9          glucose(4)
# rpoB__rpoBE546V_044__1              M9          glucose(4)
# rpoB__rpoBE546V_lb__1               LB                 NaN
# rpoB__rpoBE546V_lb__2               LB                 NaN
# rpoB__rpoBE546V_glc__1              M9          glucose(4)
# rpoB__rpoBE672K_glc__1              M9          glucose(4)
# rpoB__rpoBE672K_glc__2              M9          glucose(4)
# rpoB__rpoBE672K_lb__1               LB                 NaN
# rpoB__rpoBE672K_lb__2               LB                 NaN
#
#                             Nitrogen Source (g/L) Electron Acceptor  \
# Sample ID
# base__wt_glc__1                          NH4Cl(1)                O2
# base__wt_glc__2                          NH4Cl(1)                O2
# fur__wt_dpd__1                           NH4Cl(1)                O2
# fur__wt_dpd__2                           NH4Cl(1)                O2
# fur__wt_fe__1                            NH4Cl(1)                O2
# fur__wt_fe__2                            NH4Cl(1)                O2
# fur__delfur_dpd__1                       NH4Cl(1)                O2
# fur__delfur_dpd__2                       NH4Cl(1)                O2
# fur__delfur_fe2__1                       NH4Cl(1)                O2
# fur__delfur_fe2__2                       NH4Cl(1)                O2
# acid__wt_ph5__1                          NH4Cl(1)                O2
# acid__wt_ph5__2                          NH4Cl(1)                O2
# acid__delgadx_ph5__1                     NH4Cl(1)                O2
# acid__delgadx_ph5__2                     NH4Cl(1)                O2
# acid__delgadw_ph5__1                     NH4Cl(1)                O2
# acid__delgadw_ph5__2                     NH4Cl(1)                O2
# acid__delgade_ph5__1                     NH4Cl(1)                O2
# acid__delgade_ph5__2                     NH4Cl(1)                O2
# oxidative__wt_pq__1                      NH4Cl(1)                O2
# oxidative__wt_pq__2                      NH4Cl(1)                O2
# oxidative__deloxyr_pq__1                 NH4Cl(1)                O2
# oxidative__deloxyr_pq__2                 NH4Cl(1)                O2
# oxidative__delsoxr_pq__1                 NH4Cl(1)                O2
# oxidative__delsoxr_pq__2                 NH4Cl(1)                O2
# oxidative__delsoxs_pq__1                 NH4Cl(1)                O2
# oxidative__delsoxs_pq__2                 NH4Cl(1)                O2
# nac_ntrc__wt_csn__1                   cytosine(2)                O2
# nac_ntrc__wt_csn__2                   cytosine(2)                O2
# nac_ntrc__wt_cytd__1                  cytidine(2)                O2
# cra_crp__wt_fru__2                       NH4Cl(1)                O2
# cra_crp__delcra_ac__1                    NH4Cl(1)                O2
# cra_crp__delcra_ac__2                    NH4Cl(1)                O2
# cra_crp__delcra_fru__1                   NH4Cl(1)                O2
# cra_crp__delcra_fru__2                   NH4Cl(1)                O2
# cra_crp__delcra_glc__1                   NH4Cl(1)                O2
# cra_crp__delcra_glc__2                   NH4Cl(1)                O2
# rpoB__wt_031__1                          NH4Cl(1)                O2
# rpoB__wt_044__1                          NH4Cl(1)                O2
# rpoB__wt_lb__1                                NaN                O2
# rpoB__wt_lb__2                                NaN                O2
# rpoB__rpoBE546V_031__1                   NH4Cl(1)                O2
# rpoB__rpoBE546V_044__1                   NH4Cl(1)                O2
# rpoB__rpoBE546V_lb__1                         NaN                O2
# rpoB__rpoBE546V_lb__2                         NaN                O2
# rpoB__rpoBE546V_glc__1                   NH4Cl(1)                O2
# rpoB__rpoBE672K_glc__1                   NH4Cl(1)                O2
# rpoB__rpoBE672K_glc__2                   NH4Cl(1)                O2
# rpoB__rpoBE672K_lb__1                         NaN                O2
# rpoB__rpoBE672K_lb__2                         NaN                O2
#
#                                        Trace Element Mixture  \
# Sample ID
# base__wt_glc__1                  sauer trace element mixture
# base__wt_glc__2                  sauer trace element mixture
# fur__wt_dpd__1                                           NaN
# fur__wt_dpd__2                                           NaN
# fur__wt_fe__1                                            NaN
# fur__wt_fe__2                                            NaN
# fur__delfur_dpd__1                                       NaN
# fur__delfur_dpd__2                                       NaN
# fur__delfur_fe2__1                                       NaN
# fur__delfur_fe2__2                                       NaN
# acid__wt_ph5__1                                          NaN
# acid__wt_ph5__2                                          NaN
# acid__delgadx_ph5__1                                     NaN
# acid__delgadx_ph5__2                                     NaN
# acid__delgadw_ph5__1                                     NaN
# acid__delgadw_ph5__2                                     NaN
# acid__delgade_ph5__1                                     NaN
# acid__delgade_ph5__2                                     NaN
# oxidative__wt_pq__1                                      NaN
# oxidative__wt_pq__2                                      NaN
# oxidative__deloxyr_pq__1                                 NaN
# oxidative__deloxyr_pq__2                                 NaN
# oxidative__delsoxr_pq__1                                 NaN
# oxidative__delsoxr_pq__2                                 NaN
# oxidative__delsoxs_pq__1                                 NaN
# oxidative__delsoxs_pq__2                                 NaN
# nac_ntrc__wt_csn__1                                      NaN
# nac_ntrc__wt_csn__2                                      NaN
# nac_ntrc__wt_cytd__1                                     NaN
# nac_ntrc__wt_cytd__2                                     NaN
# nac_ntrc__wt_gln__1                                      NaN
# nac_ntrc__wt_gln__2                                      NaN
# nac_ntrc__bw_delnac_csn__1                               NaN
# nac_ntrc__bw_delnac_csn__2                               NaN
# nac_ntrc__bw_delnac_cytd__1                              NaN
# nac_ntrc__bw_delnac_cytd__2                              NaN
# nac_ntrc__bw_delnac_gln__1                               NaN
# nac_ntrc__bw_delnac_gln__2                               NaN
# nac_ntrc__bw_delnac_nh4__1                               NaN
# nac_ntrc__bw_delnac_nh4__2                               NaN
# misc__wt_no_te__1                                        NaN
# misc__wt_no_te__2                                        NaN
# misc__bw_delcbl__1               sauer trace element mixture
# misc__bw_delcbl__2               sauer trace element mixture
# misc__bw_delfabr__1              sauer trace element mixture
# misc__bw_delfabr__2              sauer trace element mixture
# misc__bw_delfadr__1              sauer trace element mixture
# misc__bw_delfadr__2              sauer trace element mixture
# omics__wt_glu__1                 sauer trace element mixture
# omics__wt_glu__2                 sauer trace element mixture
# omics__wt_gly__1                 sauer trace element mixture
# omics__wt_gly__2                 sauer trace element mixture
# omics__wt_thr__1                 sauer trace element mixture
# omics__wt_thr__2                 sauer trace element mixture
# omics__bw_ac__1              aebersold trace element mixture
# omics__bw_ac__2              aebersold trace element mixture
# omics__bw_fum__1             aebersold trace element mixture
# omics__bw_fum__2             aebersold trace element mixture
# omics__bw_glc__1             aebersold trace element mixture
# omics__bw_glc__2             aebersold trace element mixture
# omics__bw_pyr__1             aebersold trace element mixture
# omics__bw_pyr__2             aebersold trace element mixture
# ompr__wt_nacl__1                                         NaN
# ompr__bw_delompr_nacl__1                                 NaN
# ompr__bw_delompr_nacl__2                                 NaN
# minspan__wt_ade__1               sauer trace element mixture
# minspan__wt_glc__1               sauer trace element mixture
# minspan__wt_glc__2               sauer trace element mixture
# minspan__wt_glc__3               sauer trace element mixture
# minspan__wt_glc__4               sauer trace element mixture
# minspan__wt_glc_anaero__1        sauer trace element mixture
# minspan__wt_glc_anaero__2        sauer trace element mixture
# minspan__wt_trp__1               sauer trace element mixture
# minspan__bw_delcra_glc__1        sauer trace element mixture
# minspan__bw_delcra_glc__2        sauer trace element mixture
# minspan__bw_delcra_trp__1        sauer trace element mixture
# minspan__bw_delmntr__1           sauer trace element mixture
# minspan__bw_delnac_ade__1        sauer trace element mixture
# minspan__bw_delnac_glc__1        sauer trace element mixture
# cra_crp__wt_ac__1            aebersold trace element mixture
# cra_crp__wt_ac__2            aebersold trace element mixture
# cra_crp__wt_fru__1           aebersold trace element mixture
# cra_crp__wt_fru__2           aebersold trace element mixture
# cra_crp__delcra_ac__1        aebersold trace element mixture
# cra_crp__delcra_ac__2        aebersold trace element mixture
# cra_crp__delcra_fru__1       aebersold trace element mixture
# cra_crp__delcra_fru__2       aebersold trace element mixture
# cra_crp__delcra_glc__1       aebersold trace element mixture
# cra_crp__delcra_glc__2       aebersold trace element mixture
# rpoB__wt_031__1                                          NaN
# rpoB__wt_044__1                                          NaN
# rpoB__wt_lb__1                                           NaN
# rpoB__wt_lb__2                                           NaN
# rpoB__rpoBE546V_031__1           sauer trace element mixture
# rpoB__rpoBE546V_044__1           sauer trace element mixture
# rpoB__rpoBE546V_lb__1                                    NaN
# rpoB__rpoBE546V_lb__2                                    NaN
# rpoB__rpoBE546V_glc__1           sauer trace element mixture
# rpoB__rpoBE672K_glc__1           sauer trace element mixture
# rpoB__rpoBE672K_glc__2           sauer trace element mixture
# rpoB__rpoBE672K_lb__1                                    NaN
# rpoB__rpoBE672K_lb__2                                    NaN
#
#                                               Supplement  Temperature (C)  \
# Sample ID
# base__wt_glc__1                                      NaN               37
# base__wt_glc__2                                      NaN               37
# fur__wt_dpd__1                                DPD(0.2mM)               37
# fur__wt_dpd__2                                DPD(0.2mM)               37
# fur__wt_fe__1                               FeCl2(0.1mM)               37
# fur__wt_fe__2                               FeCl2(0.1mM)               37
# fur__delfur_dpd__1                            DPD(0.2mM)               37
# fur__delfur_dpd__2                            DPD(0.2mM)               37
# fur__delfur_fe2__1                          FeCl2(0.1mM)               37
# fur__delfur_fe2__2                          FeCl2(0.1mM)               37
# acid__wt_ph5__1                                      NaN               37
# acid__wt_ph5__2                                      NaN               37
# acid__delgadx_ph5__1                                 NaN               37
# acid__delgadx_ph5__2                                 NaN               37
# acid__delgadw_ph5__1                                 NaN               37
# acid__delgadw_ph5__2                                 NaN               37
# acid__delgade_ph5__1                                 NaN               37
# acid__delgade_ph5__2                                 NaN               37
# oxidative__wt_pq__1                            PQ(250uM)               37
# oxidative__wt_pq__2                            PQ(250uM)               37
# oxidative__deloxyr_pq__1                       PQ(250uM)               37
# oxidative__deloxyr_pq__2                       PQ(250uM)               37
# oxidative__delsoxr_pq__1                       PQ(250uM)               37
# oxidative__delsoxr_pq__2                       PQ(250uM)               37
# oxidative__delsoxs_pq__1                       PQ(250uM)               37
# oxidative__delsoxs_pq__2                       PQ(250uM)               37
# nac_ntrc__wt_csn__1                                  NaN               37
# nac_ntrc__wt_csn__2                                  NaN               37
# nac_ntrc__wt_cytd__1                                 NaN               37
# nac_ntrc__wt_cytd__2                                 NaN               37
# nac_ntrc__wt_gln__1                                  NaN               37
# nac_ntrc__wt_gln__2                                  NaN               37
# nac_ntrc__bw_delnac_csn__1                           NaN               37
# nac_ntrc__bw_delnac_csn__2                           NaN               37
# nac_ntrc__bw_delnac_cytd__1                          NaN               37
# nac_ntrc__bw_delnac_cytd__2                          NaN               37
# nac_ntrc__bw_delnac_gln__1                           NaN               37
# nac_ntrc__bw_delnac_gln__2                           NaN               37
# nac_ntrc__bw_delnac_nh4__1                           NaN               37
# nac_ntrc__bw_delnac_nh4__2                           NaN               37
# misc__wt_no_te__1                                    NaN               37
# misc__wt_no_te__2                                    NaN               37
# misc__bw_delcbl__1                                   NaN               37
# misc__bw_delcbl__2                                   NaN               37
# misc__bw_delfabr__1                                  NaN               37
# misc__bw_delfabr__2                                  NaN               37
# misc__bw_delfadr__1                                  NaN               37
# misc__bw_delfadr__2                                  NaN               37
# omics__wt_glu__1                         glutamate(10mM)               37
# omics__wt_glu__2                         glutamate(10mM)               37
# omics__wt_gly__1                           glycine(10mM)               37
# omics__wt_gly__2                           glycine(10mM)               37
# omics__wt_thr__1                         threonine(10mM)               37
# omics__wt_thr__2                         threonine(10mM)               37
# omics__bw_ac__1              thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_ac__2              thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_fum__1             thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_fum__2             thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_glc__1             thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_glc__2             thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_pyr__1             thiamine(1.4mM),FeCl3(60uM)               37
# omics__bw_pyr__2             thiamine(1.4mM),FeCl3(60uM)               37
# ompr__wt_nacl__1                              NaCl(0.3M)               37
# ompr__bw_delompr_nacl__1                      NaCl(0.3M)               37
# ompr__bw_delompr_nacl__2                      NaCl(0.3M)               37
# minspan__wt_ade__1                       adenine (10 mM)               37
# minspan__wt_glc__1                                   NaN               37
# minspan__wt_glc__2                                   NaN               37
# minspan__wt_glc__3                                   NaN               37
# minspan__wt_glc__4                                   NaN               37
# minspan__wt_glc_anaero__1                            NaN               37
# minspan__wt_glc_anaero__2                            NaN               37
# minspan__wt_trp__1                L-tryptophan (20 mg/L)               37
# minspan__bw_delcra_glc__1                            NaN               37
# minspan__bw_delcra_glc__2                            NaN               37
# minspan__bw_delcra_trp__1         L-tryptophan (20 mg/L)               37
# minspan__bw_delmntr__1                               NaN               37
# minspan__bw_delnac_ade__1                adenine (10 mM)               37
# minspan__bw_delnac_glc__1                            NaN               37
# cra_crp__wt_ac__1                                    NaN               37
# cra_crp__wt_ac__2                                    NaN               37
# cra_crp__wt_fru__1                                   NaN               37
# cra_crp__wt_fru__2                                   NaN               37
# cra_crp__delcra_ac__1                                NaN               37
# cra_crp__delcra_ac__2                                NaN               37
# cra_crp__delcra_fru__1                               NaN               37
# cra_crp__delcra_fru__2                               NaN               37
# cra_crp__delcra_glc__1                               NaN               37
# cra_crp__delcra_glc__2                               NaN               37
# rpoB__wt_031__1                                      NaN               37
# rpoB__wt_044__1                                      NaN               37
# rpoB__wt_lb__1                                       NaN               37
# rpoB__wt_lb__2                                       NaN               37
# rpoB__rpoBE546V_031__1                               NaN               37
# rpoB__rpoBE546V_044__1                               NaN               37
# rpoB__rpoBE546V_lb__1                                NaN               37
# rpoB__rpoBE546V_lb__2                                NaN               37
# rpoB__rpoBE546V_glc__1                               NaN               37
# rpoB__rpoBE672K_glc__1                               NaN               37
# rpoB__rpoBE672K_glc__2                               NaN               37
# rpoB__rpoBE672K_lb__1                                NaN               37
# rpoB__rpoBE672K_lb__2                                NaN               37
#
#                               pH Culture Type  Growth Rate (1/hr)  \
# Sample ID
# base__wt_glc__1              7.0        Batch                 NaN
# base__wt_glc__2              7.0        Batch                 NaN
# fur__wt_dpd__1               7.0        Batch            0.000000
# fur__wt_dpd__2               7.0        Batch            0.000000
# fur__wt_fe__1                7.0        Batch            1.060606
# fur__wt_fe__2                7.0        Batch            1.060606
# fur__delfur_dpd__1           7.0        Batch            0.000000
# fur__delfur_dpd__2           7.0        Batch            0.000000
# fur__delfur_fe2__1           7.0        Batch            0.619469
# fur__delfur_fe2__2           7.0        Batch            0.619469
# acid__wt_ph5__1              5.5        Batch                 NaN
# acid__wt_ph5__2              5.5        Batch                 NaN
# acid__delgadx_ph5__1         5.5        Batch                 NaN
# acid__delgadx_ph5__2         5.5        Batch                 NaN
# acid__delgadw_ph5__1         5.5        Batch                 NaN
# acid__delgadw_ph5__2         5.5        Batch                 NaN
# acid__delgade_ph5__1         5.5        Batch                 NaN
# acid__delgade_ph5__2         5.5        Batch                 NaN
# oxidative__wt_pq__1          7.0        Batch            0.000000
# oxidative__wt_pq__2          7.0        Batch            0.000000
# oxidative__deloxyr_pq__1     7.0        Batch            0.000000
# oxidative__deloxyr_pq__2     7.0        Batch            0.000000
# oxidative__delsoxr_pq__1     7.0        Batch            0.000000
# oxidative__delsoxr_pq__2     7.0        Batch            0.000000
# oxidative__delsoxs_pq__1     7.0        Batch            0.000000
# oxidative__delsoxs_pq__2     7.0        Batch            0.000000
# nac_ntrc__wt_csn__1          7.0        Batch                 NaN
# nac_ntrc__wt_csn__2          7.0        Batch                 NaN
# nac_ntrc__wt_cytd__1         7.0        Batch                 NaN
# nac_ntrc__wt_cytd__2         7.0        Batch                 NaN
# nac_ntrc__wt_gln__1          7.0        Batch                 NaN
# nac_ntrc__wt_gln__2          7.0        Batch                 NaN
# nac_ntrc__bw_delnac_csn__1   7.0        Batch                 NaN
# nac_ntrc__bw_delnac_csn__2   7.0        Batch                 NaN
# nac_ntrc__bw_delnac_cytd__1  7.0        Batch                 NaN
# nac_ntrc__bw_delnac_cytd__2  7.0        Batch                 NaN
# nac_ntrc__bw_delnac_gln__1   7.0        Batch                 NaN
# nac_ntrc__bw_delnac_gln__2   7.0        Batch                 NaN
# nac_ntrc__bw_delnac_nh4__1   7.0        Batch                 NaN
# nac_ntrc__bw_delnac_nh4__2   7.0        Batch                 NaN
# misc__wt_no_te__1            7.0        Batch                 NaN
# misc__wt_no_te__2            7.0        Batch                 NaN
# misc__bw_delcbl__1           7.0        Batch                 NaN
# misc__bw_delcbl__2           7.0        Batch                 NaN
# misc__bw_delfabr__1          7.0        Batch                 NaN
# misc__bw_delfabr__2          7.0        Batch                 NaN
# misc__bw_delfadr__1          7.0        Batch                 NaN
# misc__bw_delfadr__2          7.0        Batch                 NaN
# omics__wt_glu__1             7.0        Batch                 NaN
# omics__wt_glu__2             7.0        Batch                 NaN
# omics__wt_gly__1             7.0        Batch                 NaN
# omics__wt_gly__2             7.0        Batch                 NaN
# omics__wt_thr__1             7.0        Batch                 NaN
# omics__wt_thr__2             7.0        Batch                 NaN
# omics__bw_ac__1              7.0        Batch            0.203000
# omics__bw_ac__2              7.0        Batch            0.203000
# omics__bw_fum__1             7.0        Batch            0.309000
# omics__bw_fum__2             7.0        Batch            0.309000
# omics__bw_glc__1             7.0        Batch            0.607500
# ...
# misc__bw_delcbl__2                               2
# misc__bw_delfabr__1                              2
# misc__bw_delfabr__2                              2
# misc__bw_delfadr__1                              2
# misc__bw_delfadr__2                              2
# omics__wt_glu__1                                 2
# omics__wt_glu__2                                 2
# omics__wt_gly__1                                 2
# omics__wt_gly__2                                 2
# omics__wt_thr__1                                 2
# omics__wt_thr__2                                 2
# omics__bw_ac__1                                  2
# omics__bw_ac__2                                  2
# omics__bw_fum__1                                 2
# omics__bw_fum__2                                 2
# omics__bw_glc__1                                 2
# omics__bw_glc__2                                 2
# omics__bw_pyr__1                                 2
# omics__bw_pyr__2                                 2
# ompr__wt_nacl__1                                 1
# ompr__bw_delompr_nacl__1                         2
# ompr__bw_delompr_nacl__2                         2
# minspan__wt_ade__1                               1
# minspan__wt_glc__1                               3
# minspan__wt_glc__2                               3
# minspan__wt_glc__3                               3
# minspan__wt_glc__4                               1
# minspan__wt_glc_anaero__1                        2
# minspan__wt_glc_anaero__2                        2
# minspan__wt_trp__1                               1
# minspan__bw_delcra_glc__1                        1
dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_csn__1   From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_csn__2   From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_cytd__1  From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_cytd__2  From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_gln__1   From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_gln__2   From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_nh4__1   From dissertation: https://escholarship.org/uc...
# nac_ntrc__bw_delnac_nh4__2   From dissertation: https://escholarship.org/uc...
# misc__wt_no_te__1                                                          NaN
# misc__wt_no_te__2                                                          NaN
# misc__bw_delcbl__1                                                         NaN
# misc__bw_delcbl__2                                                         NaN
# misc__bw_delfabr__1                                                        NaN
# misc__bw_delfabr__2                                                        NaN
# misc__bw_delfadr__1                                                        NaN
# misc__bw_delfadr__2                                                        NaN
# omics__wt_glu__1                                   doi.org/10.1038/ncomms13091
# omics__wt_glu__2                                   doi.org/10.1038/ncomms13091
# omics__wt_gly__1                                   doi.org/10.1038/ncomms13091
# omics__wt_gly__2                                   doi.org/10.1038/ncomms13091
# omics__wt_thr__1                                   doi.org/10.1038/ncomms13091
# omics__wt_thr__2                                   doi.org/10.1038/ncomms13091
# omics__bw_ac__1                                    doi.org/10.1038/ncomms13091
# omics__bw_ac__2                                    doi.org/10.1038/ncomms13091
# omics__bw_fum__1                                   doi.org/10.1038/ncomms13091
# omics__bw_fum__2                                   doi.org/10.1038/ncomms13091
# omics__bw_glc__1                                   doi.org/10.1038/ncomms13091
# omics__bw_glc__2                                   doi.org/10.1038/ncomms13091
# omics__bw_pyr__1                                   doi.org/10.1038/ncomms13091
# omics__bw_pyr__2                                   doi.org/10.1038/ncomms13091
# ompr__wt_nacl__1                            doi.org/10.1038/s41598-017-02110-7
# ompr__bw_delompr_nacl__1                    doi.org/10.1038/s41598-017-02110-7
# ompr__bw_delompr_nacl__2                    doi.org/10.1038/s41598-017-02110-7
# minspan__wt_ade__1                               doi.org/10.15252/msb.20145243
# minspan__wt_glc__1                               doi.org/10.15252/msb.20145243
# minspan__wt_glc__2                               doi.org/10.15252/msb.20145243
# minspan__wt_glc__3                               doi.org/10.15252/msb.20145243
# minspan__wt_glc__4                                                         NaN
# minspan__wt_glc_anaero__1                        doi.org/10.15252/msb.20145243
# minspan__wt_glc_anaero__2                        doi.org/10.15252/msb.20145243
# minspan__wt_trp__1                               doi.org/10.15252/msb.20145243
# minspan__bw_delcra_glc__1                        doi.org/10.15252/msb.20145243
# minspan__bw_delcra_glc__2                                                  NaN
# minspan__bw_delcra_trp__1                        doi.org/10.15252/msb.20145243
# minspan__bw_delmntr__1                           doi.org/10.15252/msb.20145243
# minspan__bw_delnac_ade__1                        doi.org/10.15252/msb.20145243
# minspan__bw_delnac_glc__1                        doi.org/10.15252/msb.20145243
# cra_crp__wt_ac__1                                       doi.org/10.1101/080929
# cra_crp__wt_ac__2                                       doi.org/10.1101/080929
# cra_crp__wt_fru__1                                      doi.org/10.1101/080929
# cra_crp__wt_fru__2                                      doi.org/10.1101/080929
# cra_crp__delcra_ac__1                                   doi.org/10.1101/080929
# omics__wt_gly__2              GSE59760
# omics__wt_thr__1              GSE59760
# omics__wt_thr__2              GSE59760
# omics__bw_ac__1               GSE59759
# omics__bw_ac__2               GSE59759
# omics__bw_fum__1              GSE59759
# omics__bw_fum__2              GSE59759
# omics__bw_glc__1              GSE59759
# omics__bw_glc__2              GSE59759
# omics__bw_pyr__1              GSE59759
# omics__bw_pyr__2              GSE59759
# ompr__wt_nacl__1              GSE88980
# ompr__bw_delompr_nacl__1      GSE88980
# ompr__bw_delompr_nacl__2      GSE88980
# minspan__wt_ade__1            GSE48324
# minspan__wt_glc__1            GSE48324
# minspan__wt_glc__2            GSE48324
# minspan__wt_glc__3            GSE48324
# minspan__wt_glc__4           GSE122211
# minspan__wt_glc_anaero__1     GSE48324
# minspan__wt_glc_anaero__2     GSE48324
# minspan__wt_trp__1            GSE48324
# minspan__bw_delcra_glc__1     GSE48324
# minspan__bw_delcra_glc__2    GSE122211
# minspan__bw_delcra_trp__1     GSE48324
# minspan__bw_delmntr__1        GSE48324
# minspan__bw_delnac_ade__1     GSE48324
# minspan__bw_delnac_glc__1     GSE48324
# cra_crp__wt_ac__1             GSE65643
# cra_crp__wt_ac__2             GSE65643
# cra_crp__wt_fru__1            GSE65643
# cra_crp__wt_fru__2            GSE65643
# cra_crp__delcra_ac__1         GSE65643
# cra_crp__delcra_ac__2         GSE65643
# cra_crp__delcra_fru__1        GSE65643
# cra_crp__delcra_fru__2        GSE65643
# cra_crp__delcra_glc__1        GSE65643
# cra_crp__delcra_glc__2        GSE65643
# rpoB__wt_031__1               GSE59377
# rpoB__wt_044__1               GSE59377
# rpoB__wt_lb__1                GSE59377
# rpoB__wt_lb__2                GSE59377
# rpoB__rpoBE546V_031__1        GSE59377
# rpoB__rpoBE546V_044__1        GSE59377
# rpoB__rpoBE546V_lb__1         GSE59377
# rpoB__rpoBE546V_lb__2         GSE59377
# rpoB__rpoBE546V_glc__1        GSE59377
# rpoB__rpoBE672K_glc__1        GSE59377
# rpoB__rpoBE672K_glc__2        GSE59377
# rpoB__rpoBE672K_lb__1         GSE59377
# rpoB__rpoBE672K_lb__2         GSE59377

# %% [markdown]
# Cluster 9 contains samples of Escherichia coli K-12 MG1655 rpoBE672K from the RpoB Knock-in study. There are essentially two unique conditions (different base media and resulting growth rates) and each condition has two replicates.
#
# It seems like that these samples are clustered together because of their strain, Escherichia coli K-12 MG1655 rpoBE672Kand it makes sense that they are extremely close since their conditions are very similar. All of them appear to be at lower extremes of the PCA plots (very negative value for both PC1 and PC2). I am not sure what's captured in PC1 and PC2 so I can't really comment on if the location makes sense in terms of their defining characteristics.

# %% [markdown]
# ### Describe the silhouette coefficient
#
# What is the equation for computing the silhouette coefficient? How do you interpret its value?
#
# <span style="color:red">5 points</span>

# %% [markdown]
# Silhouette coefficient is a measure of the distance of a point to its own cluster vs the nearest cluster
#
# $s(i) = \frac{b(i) - a(i)}{max(a(i),b(i)}$
# where a(i) = mean distance of sample to points in the same cluster
# where b(i) = mean distance of sample to points in the next closest cluster
#
# I know that during lecture you mentioned that the silhouette coefficient should always be positive, but I don't think that was accurate according to the way the formula is defined. I think there are three possibilities for the dilhouette coefficient of a sample point:
# - case 1: b(i) > a(i), where the coefficient will be positive. This is expected for a good cluster and means that the sample point is clearly within its own cluster compared to the closest neighbor.
# - case 2: b(i) = a(i), where the coefficient will be 0. Realistically, the two values are probably not going to be exactly the same, but they can be very close to the point that the coefficient is approximately 0. This means the sample point is equally close to its own cluster and the neighboring cluster. Thus the classfication of this particular sample point is very ambiguous, and perhaps the two clusters in question are not very clearly distinguished either.
# - case 3: b(i) < a(i), where the coefficient will be negative. This would be the case of a bad clustering result, because the point should probably be clustered to the next closest cluster instead of the one that it is in.

# %% [markdown]
# ### Characterize the samples using silhouette coefficients
#
# Visualize [the silhouette coefficients for each sample](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_samples.html) from your K = 10 clustering, being sure to keep the coloring and labeling consistent between this plot and the PCA_cluster_plot() from 1.2.2.
#
# Comment on how the silhouette scores relate to the cluster distribution. Note that the 2D PCA plot can't capture everything, and SCs may depend on distances in dimensions that we can't see here.
#
# <span style="color:red">10 points</span>

# %%
# the plotting codes are the example code found from sklearn website

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
X, y = make_blobs(
    n_samples=500,
    n_features=2,
    centers=4,
    cluster_std=1,
    center_box=(-10.0, 10.0),
    shuffle=True,
    random_state=1,
)  # For reproducibility

range_n_clusters = [2, 3, 4, 5, 6]

# %%
clusterer = KMeans(n_clusters=2, n_init="auto", random_state=10).fit(X)
cluster_labels = clusterer.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_57036/3343710870.py in <module>
# ----> 1 clusterer = KMeans(n_clusters=2, n_init="auto", random_state=10).fit(X)
#       2 cluster_labels = clusterer.fit_predict(X)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     982                                 accept_large_sparse=False)
#     983
# --> 984         self._check_params(X)
#     985         random_state = check_random_state(self.random_state)
#     986         sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in _check_params(self, X)
#     798
#     799         # n_init
# --> 800         if self.n_init <= 0:
#     801             raise ValueError(
#     802                 f"n_init should be > 0, got {self.n_init} instead.")
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
s_dis= metrics.silhouette_samples(data_T, kmeans.labels_)

# the plotting codes are the example code found from sklearn website

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
X, y = make_blobs(
    n_samples=500,
    n_features=2,
    centers=4,
    cluster_std=1,
    center_box=(-10.0, 10.0),
    shuffle=True,
    random_state=1,
)  # For reproducibility

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_57036/361908093.py in <module>
#      42     # seed of 10 for reproducibility.
#      43     clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=10)
# ---> 44     cluster_labels = clusterer.fit_predict(X)
#      45
#      46     # The silhouette_score gives the average value for all the samples.
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1075             Index of the cluster each sample belongs to.
#    1076         """
# -> 1077         return self.fit(X, sample_weight=sample_weight).labels_
#    1078
#    1079     def fit_transform(self, X, y=None, sample_weight=None):
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     982                                 accept_large_sparse=False)
#     983
# --> 984         self._check_params(X)
#     985         random_state = check_random_state(self.random_state)
#     986         sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in _check_params(self, X)
#     798
#     799         # n_init
# --> 800         if self.n_init <= 0:
#     801             raise ValueError(
#     802                 f"n_init should be > 0, got {self.n_init} instead.")
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Choose an optimal K with the Elbow Method
#
# Describe the elbow method and the reasoning behind using it. Using the [silhouette score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html) as your metric, find the best k using the elbow method. Be sure to understand the difference between this use of silhouette scores and the one used above.
#
# <span style="color:red">10 points</span>

# %% [markdown]
# ## Agglomerative Hierarchical Clustering
#
# [This lecture might be helpful.](https://www.andrew.cmu.edu/user/achoulde/95791/lectures/lecture07/lecture07_95791.pdf)
#
# ### Describe Agglomerative Hierarchical Clustering
#
# Use words to describe:
#
# 1. The overall criteria for agglomerative hierarchical clustering
# 2. The types of linkages (single, complete, & average), what they mean, and how they affect the resulting clusters
# 3. Its strengths and weaknesses
#
# <span style="color:red">5 points</span>

# %% [markdown]
# ### Compute Agglomerative Hierarchical Clusters
#
# #### Create dendrograms for two linkage types
#
# Use agglomerative clustering with single and complete linkage types and display *full* dendrograms for each. Comment on how the structure changes.
#
# <span style="color:red">5 points</span>

# %% [markdown]
# #### Obtain cluster labels from dendrograms
#
# Look at the dendrogram for your complete linkage model. Choose 2 different distance_thresholds or n_clusters, then obtain cluster labels for each. Re-use the provided PCA_cluster_plot() function from section 1.2.2 for each of these two sets of clusters. Notice how the change in threshold breaks up the clusters at each step.
#
# <span style="color:red">10 points</span>

# %% [markdown]
# ## Principal Component Analysis
#
# ### Describe PCA
#
# Read ["A tutorial on Principal Component Analysis" by Jonathon Shlens](https://arxiv.org/pdf/1404.1100.pdf). Summarize:
#
# 1. The PCA workflow
# 2. Its practical uses
# 3. The weaknesses and assumptions of PCA
#
# <span style="color:red">5 points</span>

# %% [markdown]
# ### Covariance
#
# #### Compute and visualize the covariance matrix.
#
# One of the major intermediate steps of computing PCA with eigendecomposition is the construction of the covariance matrix. Compute the covariance matrix for the *genes* in the *normalized* data. Visualize a clustermap of it.
#
# Note that the diagonal values should all be equal to 1 since the data has been normalized.
#
# <span style="color:red">5 points</span>

# %% [markdown]
# ### PCA of the data
#
# #### Highest weighted genes in PC 1 & PC 2
#
# Compute PCA. List the 5 genes with the highest absolute component weighting from PC 1. Does this suggest a common theme for PC1, and if so, what might it be?
#
# Repeat for the top 5 highest absolute weightings from PC 2.
#
# What does it mean for a gene to be highly weighted in one of the top components?
#
# <span style="color:red">10 points</span>

# %% [markdown]
# #### Generate a biplot
#
# Generate a biplot of the data, which is like a scatter plot of samples, but also includes a few arrows showing the directions of the genes that contribute most strongly to the first two components. Make sure the explained variance of the PCs are included in the axes labels.
#
# <span style="color:red">5 points</span>

# %% [markdown]
# #### Are any PCs correlated with growth rate?
#
# It is interesting to see if the components of a gene expression matrix correlate with phenotypic values. The only quantitative phenotype we have available for this dataset is the growth rate (stored in `sample_table['Growth Rate (1/hr)']`). Iterate through all the PCs and see which one's sample loadings have the highest (absolute value) pearson R correlation with growth rate. Plot the relationship and discuss your results.
#
# Growth rate is not available for all samples, so only include the samples that have a matched growth rate.
#
# <span style="color:red">5 points</span>

# %% [markdown]
# ### Explained Variance
#
# #### Plot the Explained Variance
#
# Create a plot of cumulative explained variance for the components in your PCA decomposition. How many components are necessary to explain 80% of the variance in the data?
#
# <span style="color:red">5 points</span>

# %% [markdown]
# #### "Denoise" your dataset
#
# It is sometimes assumed that the least explanatory PCs are the result of experimental noise. Find the number of components needed to explain 95% of the variance in the normalized data, then remove the least explanatory components and reconstruct the normalized dataset without them.
#
# Subtract the original normalized dataset from your reconstruction, and visualize the effect of denoising on the values. Is your visualization consistent with the removed effects being only noise?
#
# <span style="color:red">5 points</span>
